# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.optimize import curve_fit

# %%
df = pd.read_csv('comb_sort_data.csv')
print(df)

# %%
x = np.array(df.iloc[:, 1])
y = np.array(df.iloc[:, 0])

# %%
plt.scatter(x, y)
plt.xlabel('n')
plt.ylabel('Time, ms')
plt.title('Comb sort')
