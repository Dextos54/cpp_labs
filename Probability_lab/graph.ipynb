# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('data/normal_dice_1_100.csv')
plt.scatter(data['value'], data['probability'])
plt.xlabel("value")
plt.ylabel("probability")
plt.title("normal_dice_1_100")
plt.show()

# %%
data = pd.read_csv('data/bonus_dice_1_100.csv')
plt.scatter(data['value'], data['probability'])
plt.xlabel("value")
plt.ylabel("probability")
plt.title("bonus_dice_1_100")
plt.show()

# %%
data = pd.read_csv('data/penalty_dice_1_100.csv')
plt.scatter(data['value'], data['probability'])
plt.xlabel("value")
plt.ylabel("probability")
plt.title("penalty_dice_1_100")
plt.show()

# %%
data = pd.read_csv('data/normal_threeD6_3_18.csv')
plt.xlabel("value")
plt.ylabel("probability")
plt.title("normal_threeD6_3_18")
plt.scatter(data['value'], data['probability'])
plt.show()

# %%
data = pd.read_csv('data/bonus_threeD6_3_18.csv')
plt.xlabel("value")
plt.ylabel("probability")
plt.title("bonus_threeD6_3_18")
plt.scatter(data['value'], data['probability'])
plt.show()

# %%
data = pd.read_csv('data/penalty_threeD6_3_18.csv')
plt.xlabel("value")
plt.ylabel("probability")
plt.title("penalty_threeD6_3_18")
plt.scatter(data['value'], data['probability'])
plt.show()

# %%
data = pd.read_csv('data/double_dice_2_100.csv')
plt.xlabel("value")
plt.ylabel("probability")
plt.title("double_dice_2_100")
plt.scatter(data['value'], data['probability'])
plt.show()
