# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([100, 250, 500, 750, 1000, 2000, 2500, 4000, 5000])

# %%
a_normal = np.array([49, 68, 96, 154, 194, 350, 431, 700, 835])
a_abnormal = np.array([13, 25, 51, 89, 91, 188, 222, 347, 434])

# %%
b_normal = np.array([41, 52, 92, 140, 191, 356, 422, 665, 896])
b_abnormal = np.array([13, 46, 65, 72, 94, 174, 229, 352, 441])

# %%
c_normal = np.array([47, 55, 105, 148, 180, 353, 449, 692, 859])
c_abnormal = np.array([22, 26, 47, 65, 93, 205, 230, 340, 436])

# %%
s_normal = np.array([42, 64, 99, 164, 355, 429, 698, 715, 852])
s_abnormal = np.array([24, 34, 52, 94, 98, 174, 232, 354, 423])

# %%
plt.scatter(x, a_normal)
plt.scatter(x, a_abnormal)
plt.title("Strategy A")
plt.xlabel("Length of the array")
plt.ylabel("Time")
# Out:
# Text(0, 0.5, 'Time')

# %% [markdown]
# Asymptotic depends on the distribution

# %%
plt.scatter(x, b_normal)
plt.scatter(x, b_abnormal)
plt.title("Strategy B")
plt.xlabel("Length of the array")
plt.ylabel("Time")
# Out:
# Text(0, 0.5, 'Time')

# %% [markdown]
# Asymptotic depends on the distribution

# %%
plt.scatter(x, c_normal)
plt.scatter(x, c_abnormal)
plt.title("Strategy C")
plt.xlabel("Length of the array")
plt.ylabel("Time")
# Out:
# Text(0, 0.5, 'Time')

# %% [markdown]
# Asymptotic depends on the distribution

# %%
plt.scatter(x, s_normal)
plt.scatter(x, s_abnormal)
plt.title("Search")
plt.xlabel("Length of the array")
plt.ylabel("Time")
# Out:
# Text(0, 0.5, 'Time')

# %% [markdown]
# Asymptotic depends on the distribution

# %%
plt.scatter(x, s_normal)
plt.scatter(x, a_normal)
plt.scatter(x, b_normal)
plt.scatter(x, c_normal)
plt.title("Random")
plt.xlabel("Length of the array")
plt.ylabel("Time")
# Out:
# Text(0, 0.5, 'Time')

# %% [markdown]
# Asymptotic is almost the same

# %%
plt.scatter(x, s_abnormal)
plt.scatter(x, a_abnormal)
plt.scatter(x, b_abnormal)
plt.scatter(x, c_abnormal)
plt.title("Not random")
plt.xlabel("Length of the array")
plt.ylabel("Time")
# Out:
# Text(0, 0.5, 'Time')

# %% [markdown]
# Asymptotic is almost the same
