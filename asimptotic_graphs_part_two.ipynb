# %% [markdown]
# Import the necessary packages

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.array([100, 250, 500, 750, 1000, 2000, 2500, 4000, 5000])

# %% [markdown]
# Write the answers cpp code gave in result to different N

# %%
y_binary_search = np.array([18, 61, 100, 118, 150, 295, 343, 516, 690])
y_search = np.array([17, 40, 147, 320, 587,2468, 3578, 8903, 13804])

# %% [markdown]
# Plot them

# %%
plt.scatter(x, y_binary_search)
plt.title("Binary search")
plt.xlabel("Length of the array")
plt.ylabel("Time")
# Out:
# Text(0, 0.5, 'Time')

# %%
plt.scatter(x, y_search)
plt.title("Search")
plt.xlabel("Length of the array")
plt.ylabel("Time")
# Out:
# Text(0, 0.5, 'Time')

# %%
plt.scatter(x, y_binary_search)
plt.scatter(x, y_search)
plt.title("Both on the same plot")
plt.xlabel("Length of the array")
plt.ylabel("Time")
# Out:
# Text(0, 0.5, 'Time')

# %% [markdown]
# It can be easily seen that the first algorithm has a quadratic asimptotic and the second one has linear.
